# %% [markdown]
# # Exercise 03: Convolutional Neural Networks
#
# Course: Introduction to Deep Learning
#
# This notebook is a structured template for Sheet 03. Fill in each `TODO` section, but keep the implementations for later.

# %% [markdown]
# ## Task 1: Theory Questions
#
# Write your answers directly in the markdown cells below.

# %% [markdown]
# ### 1.1 Convolution Operation
#
# **TODO:** Compute the output size for a `5 x 5` input and a `3 x 3` kernel for:
# - no padding, stride `1`
# - padding `1`, stride `1`
# - no padding, stride `2`
#
# **TODO:** State the general output-size formula in terms of input size `W`, kernel size `K`, padding `P`, and stride `S`.
#
# **TODO:** Perform the given 2D convolution / cross-correlation by hand and show the resulting output matrix.

# %% [markdown]
# ### 1.2 Architectural Concepts
#
# **TODO:** Define the receptive field of a neuron in a CNN and explain how it grows with depth.
#
# **TODO:** Explain the purpose of max pooling, including advantages and disadvantages.
#
# **TODO:** Explain which problem residual / skip connections address in deep networks and write down the residual mapping.

# %% [markdown]
# ### 1.3 Images, Channels, and Parameter Efficiency
#
# **TODO:** Give the channel-first tensor shape for:
# - one RGB image of size `32 x 32`
# - a mini-batch of `64` such images
#
# **TODO:** For a convolutional layer with input shape `3 x 32 x 32`, `16` output channels, kernel size `3 x 3`, stride `1`, and no padding:
# - compute the number of trainable parameters including biases
# - compute the output activation shape
#
# **TODO:** For a fully connected layer from a flattened `3 x 32 x 32` input to `16` outputs:
# - compute the number of trainable parameters
# - explain why the convolutional layer is more parameter-efficient

# %% [markdown]
# ## Task 2: CNN on CIFAR-10
#
# Learning objectives:
# - build a CNN architecture in PyTorch
# - train, evaluate, and visualize CNN performance
# - visualize learned filters and a confusion matrix

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

torch.manual_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

CLASSES = ["plane", "car", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# %% [markdown]
# ### 2.1 Load and Explore CIFAR-10
#
# **TODO:** Define train and test transforms.
#
# **TODO:** Download / load the CIFAR-10 training and test datasets.
#
# **TODO:** Create data loaders.
#
# **TODO:** Visualize a few example images and their labels.
#
# **TODO:** Keep tensors and model on the same device. Use `permute(1, 2, 0)` only for plotting.

# %%
# TODO: Define transforms for training and testing

# TODO: Load CIFAR-10 datasets

# TODO: Create DataLoader objects

# TODO: Inspect dataset shapes / class distribution if useful

# TODO: Visualize sample images and labels

# %% [markdown]
# ### 2.2 Build the CNN
#
# Target architecture:
# - `Conv2d(3 -> 32, kernel_size=3, padding=1)`
# - `BatchNorm2d + ReLU`
# - `Conv2d(32 -> 32, kernel_size=3, padding=1)`
# - `BatchNorm2d + ReLU + MaxPool2d(2)`
# - `Conv2d(32 -> 64, kernel_size=3, padding=1)`
# - `BatchNorm2d + ReLU`
# - `Conv2d(64 -> 64, kernel_size=3, padding=1)`
# - `BatchNorm2d + ReLU + MaxPool2d(2)`
# - `Flatten + Linear(64 * 8 * 8 -> 256) + ReLU + Dropout(0.5)`
# - `Linear(256 -> 10)`

# %%
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        # TODO: Define the convolutional feature extractor
        # TODO: Define the classifier head
        pass

    def forward(self, x):
        # TODO: Implement the forward pass
        pass

# %% [markdown]
# ### 2.3 Training Loop
#
# **TODO:** Implement one training epoch that returns average loss and accuracy.
#
# **TODO:** Implement evaluation with `model.eval()` and `torch.no_grad()`.
#
# **TODO:** Instantiate the model, loss, optimizer, and training configuration.
#
# **TODO:** Train for multiple epochs and store history for later plots.

# %%
def train_epoch(model, loader, criterion, optimizer, device):
    """Train for one epoch. Returns (avg_loss, accuracy)."""
    # TODO: Move data to device
    # TODO: Forward pass
    # TODO: Compute loss
    # TODO: Backward pass and optimizer step
    # TODO: Track average loss and accuracy
    pass


def evaluate(model, loader, criterion, device):
    """Evaluate the model. Returns (avg_loss, accuracy)."""
    # TODO: Switch to eval mode
    # TODO: Disable gradients
    # TODO: Run inference and compute metrics
    pass


# TODO: Instantiate model = SimpleCNN(...).to(device)
# TODO: Define criterion and optimizer
# TODO: Run the training loop across epochs
# TODO: Save training / validation metrics for plotting

# %% [markdown]
# ### 2.4 Visualize Learned Filters
#
# **TODO:** Extract the filters from the first convolutional layer.
#
# **TODO:** Plot the learned filters.
#
# **TODO:** Briefly comment on whether some filters resemble edge, color-contrast, or other local pattern detectors.

# %%
# TODO: Access the first convolutional layer weights

# TODO: Prepare filters for visualization

# TODO: Plot the filters in a grid

# TODO: Add a short interpretation of the observed patterns

# %% [markdown]
# ### 2.5 Confusion Matrix
#
# **TODO:** Collect predictions and labels on the test set.
#
# **TODO:** Compute a confusion matrix.
#
# **TODO:** Visualize it and identify common confusions between classes.

# %%
# TODO: Gather predictions and true labels from the test set

# TODO: Compute the confusion matrix

# TODO: Plot the confusion matrix with readable class labels

# %% [markdown]
# ## Task 3: Adversarial Examples (Bonus)
#
# Learning objectives:
# - implement the Fast Gradient Sign Method (FGSM)
# - understand adversarial vulnerability of neural networks
# - visualize adversarial perturbations

# %% [markdown]
# ### 3.1 Load a Trained Model
#
# **TODO:** Reuse the trained model from Task 2 or load a pretrained checkpoint.
#
# **TODO:** Switch the model to evaluation mode.
#
# **TODO:** Load the CIFAR-10 test set without augmentation.

# %%
# Reuse the model from Task 2 and make sure it is in eval mode
model.eval()

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)),
])

# TODO: Load the CIFAR-10 test dataset without augmentation
# TODO: Create the corresponding test loader

# %% [markdown]
# ### 3.2 Implement FGSM
#
# **TODO:** Implement the FGSM attack
#
# $$x_{adv} = x + \epsilon \cdot \mathrm{sign}(\nabla_x \mathcal{L}(x, y, \theta))$$
#
# **TODO:** Clamp adversarial images back to a valid value range.

# %%
def fgsm_attack(model, images, labels, epsilon, criterion):
    """Generate adversarial examples using FGSM."""
    # TODO: Enable gradients for the input images
    # TODO: Run a forward pass and compute the loss
    # TODO: Backpropagate to obtain gradients w.r.t. the inputs
    # TODO: Apply the FGSM perturbation
    # TODO: Clamp the adversarial images to a valid range
    pass

# %% [markdown]
# ### 3.3 Evaluate Robustness
#
# **TODO:** Evaluate test accuracy under FGSM attacks for `epsilon in {0, 0.01, 0.05, 0.1, 0.2, 0.3}`.
#
# **TODO:** Plot or summarize the accuracy drop as `epsilon` increases.

# %%
# TODO: Loop over epsilon values

# TODO: Generate adversarial examples for each batch

# TODO: Measure and store adversarial accuracy

# TODO: Visualize or print the robustness results

# %% [markdown]
# ### 3.4 Visualize Adversarial Examples
#
# **TODO:** Show original and adversarial images side by side.
#
# **TODO:** Include predicted labels for both versions.

# %%
# TODO: Select a few examples for visualization

# TODO: Plot original vs. adversarial images side by side

# TODO: Display the corresponding predictions

# %% [markdown]
# ### 3.5 Reflection
#
# **TODO:** Answer whether the perturbations are visible to the human eye at `epsilon = 0.1`.
#
# **TODO:** Explain why FGSM works and which property of neural networks it exploits.
#
# **TODO:** Propose one possible defense mechanism against adversarial examples.
